# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df =pd.read_excel(r"C:\Users\cherry\Downloads\Sample - Superstore.xls")

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.load_dataset("car_crashes")
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ## Histogram using sns

# %%
sns.histplot(df['Sales'])
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %% [markdown]
# ## Box plot using sns

# %%
plt.figure(figsize = (12,6))
sns.boxplot(df['Sales'])
# Out:
# <Axes: ylabel='Sales'>

# %%
plt.figure(figsize = (12,6))
sns.boxplot(data = df, x = 'Category', y = 'Sales')
plt.title('Boxplot of Profit by Category')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Violin Plot using sns

# %%
plt.figure(figsize = (12,6))
sns.violinplot(data = df, x = 'Category', y = 'Sales')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Count plot using sns

# %%
plt.figure(figsize = (12,6))
sns.countplot(data = df, x = 'Region')
plt.title('Count Plot of Orders by Region')
plt.show()

# %%
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %% [markdown]
# ## Bar plot using sns, we can use estimator = np.sum, np.mean, np.std, np.var, np.count

# %%
plt.figure(figsize  = (12,6))
sns.barplot(data = df, x = 'Ship Mode', y = 'Sales', estimator = np.sum)
plt.title('Bar Plot of Profit by Ship Mode')
# Out:
# Text(0.5, 1.0, 'Bar Plot of Profit by Ship Mode')

# %% [markdown]
# ## Line plot

# %%
plt.figure(figsize = (12,6))
sns.lineplot(data = df, x = 'Order Date', y = 'Sales')
plt.title('Line Plot of Sales over Time')
plt.show()

# %% [markdown]
# ## Scatter Plot, hue = category means it gives different colors for different categories

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='Sales', y='Profit', hue='Category')
plt.title('Scatter Plot of Sales vs Profit by Category')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='Sales', y='Profit')
plt.title('Scatter Plot of Sales vs Profit by Category')
plt.show()

# %% [markdown]
# ## Heat Map

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df['Sales'].values[0:100].reshape(10,10),annot=True,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ## Swarm Plot

# %%
sns.swarmplot(data=df.sample(1000), x='Category', y='Sales')
# Out:
# D:\edukron_python_software\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 88.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\edukron_python_software\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 64.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\edukron_python_software\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 60.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Category', ylabel='Sales'>
# D:\edukron_python_software\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 90.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ## Regression Plot , y = mx+c draws a line between two sides

# %%
sns.regplot(data=df, x='Sales', y='Profit')
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# ## LM Plot

# %%
sns.lmplot(data=df, x='Sales', y='Profit', hue='Category')
